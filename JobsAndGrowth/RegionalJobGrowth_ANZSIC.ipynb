# %%
import pandas as pd
import numpy as np

# %%
df_path= './data/RegionalProjections_noninteractive.xls'

# %%
df_2018 = pd.read_excel(df_path, sheet_name=5, skiprows=1)
df_2023 = pd.read_excel(df_path, sheet_name=4, skiprows=1)

# %%
#clean
df_2018['Region'] = df_2018['Region'].str.strip()
df_2023['Region'] = df_2018['Region'].str.strip()

# %% [markdown]
# # Views we want
# - Given SA4 or State and ANZSIC, give the 5 year predicted growth in # and %
# - Given SA4 or State, give the top growing ANZSIC in # and %
# - Given SA4 or

# %%
regions_states   = df_2018[df_2018['Level']==1.0]['Region'].unique()
regions_gccsa    = df_2018[df_2018['Level']==2.0]['Region'].unique()
regions_sa4      = df_2018[df_2018['Level']==3.0]['Region'].unique()
anzsic_divisions = df_2018.columns[3:]

# %%
def region_and_anzsic_to_growth(region, anzsic):
    num_2018 = int(df_2018[df_2018['Region']==region][anzsic].values[0]*1000)
    num_2023 = int(df_2023[df_2023['Region']==region][anzsic].values[0]*1000)
    
    growth   = num_2023-num_2018
    growth_pc= 100*growth/num_2018
    
    return np.array([num_2018, num_2023, growth, growth_pc])

# %%
region_and_anzsic_to_growth(regions_states[2], anzsic_divisions[3])
# Out:
# array([3.57210000e+04, 3.77830000e+04, 2.06200000e+03, 5.77251477e+00])

# %%
def region_to_growth(region):
    num_2018 = (df_2018[df_2018['Region']==region][anzsic_divisions].values[0]*1000).astype(np.int)
    num_2023 = (df_2023[df_2023['Region']==region][anzsic_divisions].values[0]*1000).astype(np.int)
    
    
    
    data = zip(anzsic_divisions, num_2018, num_2023, num_2023-num_2018, 100*(num_2023-num_2018)/num_2018)
    
    
    return pd.DataFrame(data = data, columns = ['ANZSIC Division','Jobs (2018)', 'Jobs (2019)', 'Job Growth (num)', 'Job Growth (%)']).set_index('ANZSIC Division')

# %%
region_to_growth('New South Wales')
# Out:
#                                                  Jobs (2018)  Jobs (2019)  \
# ANZSIC Division
# Agriculture, Forestry and Fishing                      70108        64514
# Mining                                                 38696        38575
# Manufacturing                                         297318       302785
# Electricity, Gas, Water and Waste Services             38814        39868
# Construction                                          376390       417426
# Wholesale Trade                                       130984       128966
# Retail Trade                                          425369       449565
# Accommodation and Food Services                       277168       297783
# Transport, Postal and Warehousing                     202554       210963
# Information Media and Telecommunications               96622       104639
# Financial and Insurance Services                      193973       204369
# Rental, Hiring and Real Estate Services                79926        86627
# Professional, Scientific and Technical Services       379941       419441
# Administrative and Support Services                   129864       137933
# Public Administration and Safety                      194035       202080
# Education and Training                                322029       357746
# Health Care and Social Assistance                     519927       605008
# Arts and Recreation Services                           72658        80019
# Other Services                                        146992       150721
# Total (industry)                                     3991493      4297151
#
#                                                  Job Growth (num)  \
# ANZSIC Division
# Agriculture, Forestry and Fishing                           -5594
# Mining                                                       -121
# Manufacturing                                                5467
# Electricity, Gas, Water and Waste Services                   1054
# Construction                                                41036
# Wholesale Trade                                             -2018
# Retail Trade                                                24196
# Accommodation and Food Services                             20615
# Transport, Postal and Warehousing                            8409
# Information Media and Telecommunications                     8017
# Financial and Insurance Services                            10396
# Rental, Hiring and Real Estate Services                      6701
# Professional, Scientific and Technical Services             39500
# Administrative and Support Services                          8069
# Public Administration and Safety                             8045
# Education and Training                                      35717
# Health Care and Social Assistance                           85081
# Arts and Recreation Services                                 7361
# Other Services                                               3729
# Total (industry)                                           305658
#
#                                                  Job Growth (%)
# ANZSIC Division
# Agriculture, Forestry and Fishing                     -7.979118
# Mining                                                -0.312694
# Manufacturing                                          1.838772
# Electricity, Gas, Water and Waste Services             2.715515
# Construction                                          10.902521
# Wholesale Trade                                       -1.540646
# Retail Trade                                           5.688238
# Accommodation and Food Services                        7.437727
# Transport, Postal and Warehousing                      4.151486
# Information Media and Telecommunications               8.297282
# Financial and Insurance Services                       5.359509
# Rental, Hiring and Real Estate Services                8.384005
# Professional, Scientific and Technical Services       10.396351
# Administrative and Support Services                    6.213423
# Public Administration and Safety                       4.146159
# Education and Training                                11.091237
# Health Care and Social Assistance                     16.364028
# Arts and Recreation Services                          10.131025
# Other Services                                         2.536873
# Total (industry)                                       7.657736
